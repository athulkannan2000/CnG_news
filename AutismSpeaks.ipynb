# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

def scrape_autismspeaks_news():
    html_text = requests.get('https://www.autismspeaks.org/news?article_type[981]=981&life_stage[1041]=1041&article_type[981]=981')
    soup = BeautifulSoup(html_text.content, 'lxml')

    autismspeaks = soup.find_all('div', class_='col-12 col-md-3 grid__col')

    posts_data = []

    for index, post in enumerate(autismspeaks, start=1):
        as_title = post.find('div', class_='card__summary').text.strip()
        as_link = post.find('div', class_='card__summary').a['href']
        link = 'https://www.autismspeaks.org/' + as_link

        post_data = {
            'Index': index,
            'Title': as_title,
            'Link': link
        }

        posts_data.append(post_data)

    posts_df = pd.DataFrame(posts_data)
    return posts_df

def scrape_articles(url):
    html_text = requests.get(url)
    soup = BeautifulSoup(html_text.content, 'lxml')

    article = soup.find('div', class_='article-page')

    article_title = article.find('h1').text.strip() if article.find('h1') else None

    article_publisheddate = article.find('strong', class_='article-page__author').text.strip() if article.find('strong', class_='article-page__author') else None

    article_imgurl = article.find('div', class_='article-page__inner').img['src'] if article.find('div', class_='article-page__inner') and article.find('div', class_='article-page__inner').img else None
    imgurl = 'https://www.autismspeaks.org/' + article_imgurl if article_imgurl else None

    content_text = ""
    content_html = ""

    content_div = article.find('div', class_='article-page__inner')
    if content_div:
        for p_tag in content_div.find_all('p'):
            content_text += p_tag.text.strip() + "\n"
            content_html += str(p_tag) + "\n"

    article_data = {
        'Index': None,  # Placeholder for the index
        'Title': article_title,
        'Link': url,
        'Published date': article_publisheddate,
        'Image URL': imgurl,
        'Text content': content_text,
        'HTML content': content_html,
        'Date Fetched': pd.to_datetime('today').date()
    }

    return article_data

# Scrape autismspeaks news and print posts_df
posts_df = scrape_autismspeaks_news()
print("Posts DataFrame:")
print(posts_df)
print("\n")

# Scrape articles and print articles_df
articles_data = []

for index, row in posts_df.iterrows():
    article_data = scrape_articles(row['Link'])
    article_data['Index'] = row['Index']
    articles_data.append(article_data)

articles_df = pd.DataFrame(articles_data)
print("Articles DataFrame:")
print(articles_df)
# Out:
# Posts DataFrame:
#     Index                                              Title  \
# 0       1  NFL players show support of Autism Speaks duri...
# 1       2  Autism Speaks CEO Stands with Chicago Bears Of...
# 2       3  Charting a Path to Inclusion: A Call to Action...
# 3       4  A Letter from Autism Speaks CEO this World Aut...
# 4       5  Thomas Frazier joins the Autism Speaks Board o...
# 5       6  Autism Speaks announces 2021 Norma and Malcom ...
# 6       7  Autism Speaks applauds introduction of the Sup...
# 7       8  How to cope with disrupted family routines dur...
# 8       9        Join Us for a Brighter Life on the Spectrum
# 9      10  Autism study finds high rates of unmet healthc...
# 10     11  Autism Speaks funds promising new treatment an...
# 11     12  Autism Research Series – ‘Discovery to Solutions’
# 12     13  National survey of parents identifies 1 in 40 ...
# 13     14  Autism Speaks and Royal Arch Masons expand fun...
# 14     15  This hospital is creating an autism-friendly e...
# 15     16  Ten toys and games for autistic toddlers and c...
#
#                                                  Link
# 0   https://www.autismspeaks.org//news/nfl-players...
# 1   https://www.autismspeaks.org//news/autism-spea...
# 2   https://www.autismspeaks.org//news/charting-pa...
# 3   https://www.autismspeaks.org//news/letter-auti...
# 4   https://www.autismspeaks.org//news/thomas-fraz...
# 5   https://www.autismspeaks.org//news/autism-spea...
# 6   https://www.autismspeaks.org//news/autism-spea...
# 7   https://www.autismspeaks.org//news/how-cope-di...
# 8   https://www.autismspeaks.org//news/join-us-bri...
# 9   https://www.autismspeaks.org//news/autism-stud...
# 10  https://www.autismspeaks.org//news/autism-spea...
# 11  https://www.autismspeaks.org//news/autism-rese...
# 12  https://www.autismspeaks.org//news/national-su...
# 13  https://www.autismspeaks.org//news/autism-spea...
# 14  https://www.autismspeaks.org//news/hospital-cr...
# 15  https://www.autismspeaks.org//news/ten-autism-...
#
#
# Articles DataFrame:
#     Index                                              Title  \
# 0       1  NFL players show support of Autism Speaks duri...
# 1       2  Autism Speaks CEO Stands with Chicago Bears Of...
# 2       3  Charting a Path to Inclusion: A Call to Action...
# 3       4  A Letter from Autism Speaks CEO this World Aut...
# 4       5  Thomas Frazier joins the Autism Speaks Board o...
# 5       6  Autism Speaks announces 2021 Norma and Malcom ...
# 6       7  Autism Speaks applauds introduction of the Sup...
# 7       8  How to cope with disrupted family routines dur...
# 8       9        Join Us for a Brighter Life on the Spectrum
# 9      10  Autism study finds high rates of unmet healthc...
# 10     11  Autism Speaks funds promising new treatment an...
# 11     12  Autism Research Series – ‘Discovery to Solutions’
# 12     13  National survey of parents identifies 1 in 40 ...
# 13     14  Autism Speaks and Royal Arch Masons expand fun...
# 14     15  This hospital is creating an autism-friendly e...
# 15     16  Ten toys and games for autistic toddlers and c...
#
#                                                  Link      Published date  \
# 0   https://www.autismspeaks.org//news/nfl-players...   December 15, 2023
# 1   https://www.autismspeaks.org//news/autism-spea...    December 9, 2023
# 2   https://www.autismspeaks.org//news/charting-pa...  September 19, 2023
# 3   https://www.autismspeaks.org//news/letter-auti...      March 30, 2023
# 4   https://www.autismspeaks.org//news/thomas-fraz...         May 9, 2022
# 5   https://www.autismspeaks.org//news/autism-spea...         May 3, 2022
# 6   https://www.autismspeaks.org//news/autism-spea...     October 2, 2020
# 7   https://www.autismspeaks.org//news/how-cope-di...      March 20, 2020
# 8   https://www.autismspeaks.org//news/join-us-bri...    October 11, 2019
# 9   https://www.autismspeaks.org//news/autism-stud...    January 14, 2019
# 10  https://www.autismspeaks.org//news/autism-spea...   December 19, 2018
# 11  https://www.autismspeaks.org//news/autism-rese...   November 28, 2018
# 12  https://www.autismspeaks.org//news/national-su...   November 26, 2018
# 13  https://www.autismspeaks.org//news/autism-spea...   November 15, 2018
# 14  https://www.autismspeaks.org//news/hospital-cr...     October 9, 2018
# 15  https://www.autismspeaks.org//news/ten-autism-...   September 6, 2018
#
#                                             Image URL  \
# 0   https://www.autismspeaks.org//sites/default/fi...
# 1   https://www.autismspeaks.org//sites/default/fi...
# 2   https://www.autismspeaks.org//sites/default/fi...
# 3   https://www.autismspeaks.org//sites/default/fi...
# 4   https://www.autismspeaks.org//sites/default/fi...
# 5   https://www.autismspeaks.org//sites/default/fi...
# 6                                                None
# 7                                                None
# 8   https://www.autismspeaks.org//sites/default/fi...
# 9   https://www.autismspeaks.org//sites/default/fi...
# 10  https://www.autismspeaks.org//sites/default/fi...
# 11  https://www.autismspeaks.org//sites/default/fi...
# 12  https://www.autismspeaks.org//sites/default/fi...
# 13  https://www.autismspeaks.org//sites/default/fi...
# 14                                               None
# 15  https://www.autismspeaks.org//sites/default/fi...
#
#                                          Text content  \
# 0   Imagine owning a piece of NFL history while su...
# 1   As the CEO of Autism Speaks, I am deeply sadde...
# 2   On the sidelines of the UN General Assembly me...
# 3   Autism Speaks is committed to a clear vision: ...
# 4   Autism Speaks is pleased to announce the appoi...
# 5   114 organizations across 31 states received fu...
# 6   Thanks to the leadership of Congresswoman Eddi...
# 7   For one-on-one help and guidance, please conta...
# 8   A new campaign featuring stories across the sp...
# 9   An Autism Speaks analysis of national survey i...
# 10  Research to advance personalized wandering int...
# 11  In 2018, Autism Speaks invited community membe...
# 12  Parents of children with autism also report hi...
# 13  Highly qualified researchers invited to apply ...
# 14  An Orlando children's hospital is piloting a n...
# 15  We asked parents and experts for a list of toy...
#
#                                          HTML content Date Fetched
# 0   <p>Imagine owning a piece of NFL history while...   2024-03-19
# 1   <p><span><span><span><span><span>As the CEO of...   2024-03-19
# 2   <p><em>On the sidelines of the UN General Asse...   2024-03-19
# 3   <p>Autism Speaks is committed to a clear visio...   2024-03-19
# 4   <p>Autism Speaks is pleased to announce the ap...   2024-03-19
# 5   <p class="article-page__subtitle">114 organiza...   2024-03-19
# 6   <p>Thanks to the leadership of <a href="https:...   2024-03-19
# 7   <p><em>For one-on-one help and guidance, pleas...   2024-03-19
# 8   <p class="article-page__subtitle">A new campai...   2024-03-19
# 9   <p class="article-page__subtitle">An Autism Sp...   2024-03-19
# 10  <p class="article-page__subtitle">Research to ...   2024-03-19
# 11  <p class="article-page__subtitle">In 2018, Aut...   2024-03-19
# 12  <p class="article-page__subtitle">Parents of c...   2024-03-19
# 13  <p class="article-page__subtitle">Highly quali...   2024-03-19
# 14  <p>An Orlando children's hospital is piloting ...   2024-03-19
# 15  <p><em>We asked parents and experts for a list...   2024-03-19

# %%
articles_df.to_csv('AutismSpeaks.csv', index = False)
