# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

def scrape_healthline(url, index):
    html_text = requests.get(url)
    soup = BeautifulSoup(html_text.content, 'lxml')

    Title_element = soup.find('div', class_='css-z468a2')
    Title = Title_element.h1.text if Title_element else None

    Link = url

    img_element = soup.find('picture', class_='css-16pk1is')
    imgurl = img_element.img['src'][2:] if img_element else None

    Content_element = soup.find('article', class_='article-body css-d2znx6 undefined')
    Content = Content_element.text if Content_element else None

    HtmlContent = Content_element if Content_element else None

    return {
        'Index': index,
        'Title': Title,
        'Link': Link,
        'Image URL': imgurl,
        'Content': Content,
        'HTML Content': str(HtmlContent),
        'Date Fetched': pd.to_datetime('today').strftime('%Y-%m-%d')
    }

# List of URLs
urls = [
    'https://www.healthline.com/health/developmental-delay',
    'https://www.healthline.com/health/autism',
    'https://www.healthline.com/health/autism/signs-of-autism-in-babies?utm_source=ReadNext',
    'https://www.healthline.com/health/types-of-autism?utm_source=ReadNext',
    'https://www.healthline.com/health/aspergers-vs-autism',
    'https://www.healthline.com/health/autism/how-to-eat-if-youre-autistic?utm_source=ReadNext',
    'https://www.healthline.com/health/autism/is-autism-a-disability?utm_source=ReadNext',
    'https://www.healthline.com/health/autism/autism-misdiagnosis?utm_source=ReadNext',
    'https://www.healthline.com/health/autism-treatment?utm_source=ReadNext',
    'https://www.healthline.com/health-news/does-screen-time-cause-developmental-delays-in-young-children',
    'https://www.healthline.com/health/childrens-health/stages-of-child-development',
    'https://www.healthline.com/health/adhd/parenting-tips',
    'https://www.healthline.com/health/adhd/is-adhd-a-disability',
    'https://www.healthline.com/health/adhd/who-diagnoses-adhd#who-can-diagnose',
    'https://www.healthline.com/health/down-syndrome'
]

data = []

for index, url in enumerate(urls, start=1):
    result = scrape_healthline(url, index)
    data.append(result)

df = pd.DataFrame(data, columns=['Index', 'Title', 'Link', 'Image URL', 'Content', 'HTML Content', 'Date Fetched'])
print(df)
# Out:
#     Index                                              Title  \
# 0       1    What You Need to Know About Developmental Delay
# 1       2  Everything You Need to Know About Autism Spect...
# 2       3  Signs of Autism in Babies: A Simple Guide to D...
# 3       4               Are There Different Types of Autism?
# 4       5  What’s the Difference Between Asperger’s and A...
# 5       6              Your Guide to Eating Well with Autism
# 6       7                 Is Autism Considered a Disability?
# 7       8                 How Common Is Autism Misdiagnosis?
# 8       9                             Autism Treatment Guide
# 9      10  Excessive Screen Time for Kids Can Cause Devel...
# 10     11  Ages and Stages: How to Monitor Child Development
# 11     12           Parenting Tips for ADHD: Do’s and Don’ts
# 12     13                          ADHD: Is It a Disability?
# 13     14                                Who Diagnoses ADHD?
# 14     15                                      Down Syndrome
#
#                                                  Link  \
# 0   https://www.healthline.com/health/developmenta...
# 1            https://www.healthline.com/health/autism
# 2   https://www.healthline.com/health/autism/signs...
# 3   https://www.healthline.com/health/types-of-aut...
# 4   https://www.healthline.com/health/aspergers-vs...
# 5   https://www.healthline.com/health/autism/how-t...
# 6   https://www.healthline.com/health/autism/is-au...
# 7   https://www.healthline.com/health/autism/autis...
# 8   https://www.healthline.com/health/autism-treat...
# 9   https://www.healthline.com/health-news/does-sc...
# 10  https://www.healthline.com/health/childrens-he...
# 11  https://www.healthline.com/health/adhd/parenti...
# 12  https://www.healthline.com/health/adhd/is-adhd...
# 13  https://www.healthline.com/health/adhd/who-dia...
# 14    https://www.healthline.com/health/down-syndrome
#
#                                             Image URL  \
# 0   i0.wp.com/post.healthline.com/wp-content/uploa...
# 1                                                None
# 2   i0.wp.com/post.healthline.com/wp-content/uploa...
# 3   i0.wp.com/post.healthline.com/wp-content/uploa...
# 4   i0.wp.com/post.healthline.com/wp-content/uploa...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9   i0.wp.com/post.healthline.com/wp-content/uploa...
# 10  i0.wp.com/post.healthline.com/wp-content/uploa...
# 11  i0.wp.com/post.healthline.com/wp-content/uploa...
# 12                                               None
# 13                                               None
# 14                                               None
#
#                                               Content  \
# 0   A delay in reaching language, thinking, social...
# 1   We include products we think are useful for ou...
# 2   Most parents observe early signs of autism in ...
# 3   Share on PinterestCavan Image/Getty ImagesAuti...
# 4   Asperger’s syndrome is no longer a stand-alone...
# 5   While having autism can come along with food a...
# 6   Autism spectrum disorder (ASD), or autism, is ...
# 7   Autism can be misdiagnosed as another conditio...
# 8    What is autism?Autism spectrum disorder is a ...
# 9   Researchers say limiting children’s time with ...
# 10  Share on PinterestWe include products we think...
# 11  Share on PinterestKristen Curette & Daemaine H...
# 12  Depending on your symptoms and their impact on...
# 13  Can your primary care doctor diagnose ADHD? Or...
# 14  Down syndrome results from an extra copy of th...
#
#                                          HTML Content Date Fetched
# 0   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 1   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 2   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 3   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 4   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 5   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 6   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 7   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 8   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 9   <article class="article-body css-d2znx6 undefi...   2024-03-19
# 10  <article class="article-body css-d2znx6 undefi...   2024-03-19
# 11  <article class="article-body css-d2znx6 undefi...   2024-03-19
# 12  <article class="article-body css-d2znx6 undefi...   2024-03-19
# 13  <article class="article-body css-d2znx6 undefi...   2024-03-19
# 14  <article class="article-body css-d2znx6 undefi...   2024-03-19

# %%
df.to_csv('HealthLine.csv', index = False)
