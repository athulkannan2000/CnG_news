# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime

def scrape_tagpage(url, start_index):
    html_text = requests.get(url)
    soup = BeautifulSoup(html_text.content, 'lxml')
    
    data = []
    
    for article_index, article in enumerate(soup.find_all('article'), start=start_index):
        tag_title = article.find('h1', class_='entry-title').text.strip()
        tag_link = article.find('a')['href']
        
        print("Title:", tag_title)
        print("Link:", tag_link)
        
        data.append({
            'Index': article_index, 
            'Title': tag_title, 
            'Link': tag_link
        })
        
    return data

def scrape_articles(links_data):
    all_articles_data = []
    
    for link_data in links_data:
        link = link_data['Link']
        html_text = requests.get(link)
        soup2 = BeautifulSoup(html_text.content, 'lxml')
        
        title = soup2.find('header', class_='entry-header-site-hero').text.strip() if soup2.find('header', class_='entry-header-site-hero') else 'NaN'
        publisheddate = soup2.find('time', class_='entry-date published').text if soup2.find('time', class_='entry-date published') else 'NaN'
        imgurl = soup2.find('figure', class_='wp-caption aligncenter').img['src'] if soup2.find('figure', class_='wp-caption aligncenter') else 'NaN'
        content = soup2.find('div', class_='entry-content entry-content-single').text if soup2.find('div', class_='entry-content entry-content-single') else 'NaN'
        html_content = soup2.find('div', class_='entry-content entry-content-single') if soup2.find('div', class_='entry-content entry-content-single') else 'NaN'
        
        article_data = {
            'Index': link_data['Index'],
            'Title': title,
            'Link':link_data['Link'],
            'Published Date': publisheddate,
            'Image URL': imgurl,
            'Content': content,
            'HTML Content': html_content,
            'Data Fetched': datetime.now().strftime('%d-%m-%Y'),
        }
        
        all_articles_data.append(article_data)
        
    return all_articles_data

base_urls = [
     'https://thinkingautismguide.com/'  
]

num_pages = 3

all_data = []
current_index = 1

for base_url in base_urls:
    for page_number in range(1, num_pages + 1):  # Iterate from 1 to num_pages
        url = f'{base_url}page/{page_number}/'
        page_data = scrape_tagpage(url, current_index)  
        
        if page_data:
            all_data.extend(page_data)
            current_index += len(page_data)  # Increment the index appropriately

# Create a DataFrame from the scraped data
df_posts = pd.DataFrame(all_data)

# Scraping article details
df_articles = pd.DataFrame(scrape_articles(df_posts.to_dict(orient='records')))

print("Posts DataFrame:")
print(df_posts)

print("\nArticles DataFrame:")
print(df_articles)
# Out:
# Title: The Joy of a Sensory Friendly Home Life
# Link: https://thinkingautismguide.com/2024/03/the-joy-of-a-sensory-friendly-home-life.html
# Title: 30 Sensory Icks: A Checklist For Autistic and Neurodivergent People
# Link: https://thinkingautismguide.com/2024/02/30-sensory-icks-a-checklist-for-autistic-and-neurodivergent-people.html
# Title: Educators: How Understanding Autistic Identities Can Help You Help Your Students
# Link: https://thinkingautismguide.com/2024/02/educators-how-understanding-autistic-identities-can-help-you-help-your-students.html
# Title: Can ABA Therapy Affirm Neurodiversity?
# Link: https://thinkingautismguide.com/2024/02/can-aba-therapy-affirm-neurodiversity.html
# Title: Unheard Voices’s Shawn Sullivan Talks Autism Advocacy With TPGA
# Link: https://thinkingautismguide.com/2024/02/unheard-voicess-shawn-sullivan-talks-autism-advocacy-with-tpga.html
# Title: Natalia Speaks and the Struggle for Disability Representation in Documentaries
# Link: https://thinkingautismguide.com/2024/01/natalia-speaks-and-the-struggle-for-disability-representation-in-documentaries.html
# Link: https://thinkingautismguide.com/2023/06/book-review-the-fire-the-water-and-maudie-mcginn.html
# Title: Now That We Know Sia Is Autistic
# Link: https://thinkingautismguide.com/2023/05/now-that-we-know-sia-is-autistic.html
# Title: The Cassandra Complex: A Step Forward in Autistic Representation
# Link: https://thinkingautismguide.com/2023/05/the-cassandra-complex-a-step-forward-in-autistic-representation.html
# Title: Share the Road: The Journey to Autistry
# Link: https://thinkingautismguide.com/2023/05/share-the-road-the-journey-to-autistry.html
# Posts DataFrame:
#     Index                                              Title  \
# 0       1            The Joy of a Sensory Friendly Home Life
# 1       2  30 Sensory Icks: A Checklist For Autistic and ...
# 2       3  Educators: How Understanding Autistic Identiti...
# 3       4             Can ABA Therapy Affirm Neurodiversity?
# 4       5  Unheard Voices’s Shawn Sullivan Talks Autism A...
# 5       6  Natalia Speaks and the Struggle for Disability...
# 6       7       About Those “AI Can Diagnose Autism!” Claims
# 7       8     Why Do People Assume Autistic Play Is “Wrong”?
# 8       9  “Neurodiversity for Dummies”: A Community Conv...
# 9      10               What Do We Mean By Levels of Autism?
# 10     11  Autistic Care Workers: Willing, But Burned Out...
# 11     12  Beyond Masking and Towards Supporting Autistic...
# 12     13  Finding The Right Physical Therapist For Autis...
# 13     14  Considering Interpersonal Skills For Autistic ...
# 14     15  Diagnosed Autistic While Incarcerated: An Inte...
# 15     16  Ten Ways to Honor Autistic People Via Autism A...
# 16     17  Supporting Your Young Person Through Autistic ...
# 17     18  Ezra: Is Hollywood Getting Better at Autistic ...
# 18     19  Autistic People and the Power of Positive Nonc...
# 19     20  Grave Concerns About “Profound Autism” and Dia...
# 20     21  Work It Out! An Accessible Guide to Starting E...
# 21     22  On Being Overwhelmed By Grocery Shopping While...
# 22     23  How Gifted Labels Harm Autistic and Disabled C...
# 23     24  Heartbreak High: A Stunning Depiction of Being...
# 24     25  The Complicated Politics of Passing as Neuroty...
# 25     26  Questioning the Pathological Part of PDA: A Ta...
# 26     27  Book Review: The Fire, the Water, and Maudie M...
# 27     28                   Now That We Know Sia Is Autistic
# 28     29  The Cassandra Complex: A Step Forward in Autis...
# 29     30            Share the Road: The Journey to Autistry
#
#                                                  Link
# 0   https://thinkingautismguide.com/2024/03/the-jo...
# 1   https://thinkingautismguide.com/2024/02/30-sen...
# 2   https://thinkingautismguide.com/2024/02/educat...
# 3   https://thinkingautismguide.com/2024/02/can-ab...
# 4   https://thinkingautismguide.com/2024/02/unhear...
# 5   https://thinkingautismguide.com/2024/01/natali...
# 6   https://thinkingautismguide.com/2024/01/about-...
# 7   https://thinkingautismguide.com/2023/12/why-do...
# 8   https://thinkingautismguide.com/2023/12/neurod...
# 9   https://thinkingautismguide.com/2023/11/what-d...
# 10  https://thinkingautismguide.com/2023/11/autist...
# 11  https://thinkingautismguide.com/2023/11/beyond...
# 12  https://thinkingautismguide.com/2023/10/findin...
# 13  https://thinkingautismguide.com/2023/10/consid...
# 14  https://thinkingautismguide.com/2023/10/diagno...
# 15  https://thinkingautismguide.com/2023/10/ten-wa...
# 16  https://thinkingautismguide.com/2023/09/suppor...
# 17  https://thinkingautismguide.com/2023/09/ezra-i...
# 18  https://thinkingautismguide.com/2023/09/autist...
# 19  https://thinkingautismguide.com/2023/09/grave-...
# 20  https://thinkingautismguide.com/2023/09/work-i...
# 21  https://thinkingautismguide.com/2023/08/on-bei...
# 22  https://thinkingautismguide.com/2023/07/how-gi...
# 23  https://thinkingautismguide.com/2023/07/heartb...
# 24  https://thinkingautismguide.com/2023/07/the-co...
# 25  https://thinkingautismguide.com/2023/06/on-pda...
# 26  https://thinkingautismguide.com/2023/06/book-r...
# 27  https://thinkingautismguide.com/2023/05/now-th...
# 28  https://thinkingautismguide.com/2023/05/the-ca...
# 29  https://thinkingautismguide.com/2023/05/share-...
#
# Articles DataFrame:
#     Index                                              Title  \
# 0       1            The Joy of a Sensory Friendly Home Life
# 1       2  30 Sensory Icks: A Checklist For Autistic and ...
# 2       3  Educators: How Understanding Autistic Identiti...
# 3       4             Can ABA Therapy Affirm Neurodiversity?
# 4       5  Unheard Voices’s Shawn Sullivan Talks Autism A...
# 5       6  Natalia Speaks and the Struggle for Disability...
# 6       7       About Those “AI Can Diagnose Autism!” Claims
# 7       8     Why Do People Assume Autistic Play Is “Wrong”?
# 8       9  “Neurodiversity for Dummies”: A Community Conv...
# 9      10               What Do We Mean By Levels of Autism?
# 10     11  Autistic Care Workers: Willing, But Burned Out...
# 11     12  Beyond Masking and Towards Supporting Autistic...
# 12     13  Finding The Right Physical Therapist For Autis...
# 13     14  Considering Interpersonal Skills For Autistic ...
# 14     15  Diagnosed Autistic While Incarcerated: An Inte...
# 15     16  Ten Ways to Honor Autistic People Via Autism A...
# 16     17  Supporting Your Young Person Through Autistic ...
# 17     18  Ezra: Is Hollywood Getting Better at Autistic ...
# 18     19  Autistic People and the Power of Positive Nonc...
# 19     20  Grave Concerns About “Profound Autism” and Dia...
# 20     21  Work It Out! An Accessible Guide to Starting E...
# 21     22  On Being Overwhelmed By Grocery Shopping While...
# 22     23  How Gifted Labels Harm Autistic and Disabled C...
# 23     24  Heartbreak High: A Stunning Depiction of Being...
# 24     25  The Complicated Politics of Passing as Neuroty...
# 25     26  Questioning the Pathological Part of PDA: A Ta...
# 26     27  Book Review: The Fire, the Water, and Maudie M...
# 27     28                   Now That We Know Sia Is Autistic
# 28     29  The Cassandra Complex: A Step Forward in Autis...
# 29     30            Share the Road: The Journey to Autistry
#
#                                                  Link      Published Date  \
# 0   https://thinkingautismguide.com/2024/03/the-jo...      March 31, 2024
# 1   https://thinkingautismguide.com/2024/02/30-sen...   February 17, 2024
# 2   https://thinkingautismguide.com/2024/02/educat...                 NaN
# 3   https://thinkingautismguide.com/2024/02/can-ab...                 NaN
# 4   https://thinkingautismguide.com/2024/02/unhear...    February 4, 2024
# 5   https://thinkingautismguide.com/2024/01/natali...    January 16, 2024
# 6   https://thinkingautismguide.com/2024/01/about-...     January 4, 2024
# 7   https://thinkingautismguide.com/2023/12/why-do...                 NaN
# 8   https://thinkingautismguide.com/2023/12/neurod...    December 2, 2023
# 9   https://thinkingautismguide.com/2023/11/what-d...                 NaN
# 10  https://thinkingautismguide.com/2023/11/autist...   November 28, 2023
# 11  https://thinkingautismguide.com/2023/11/beyond...   November 18, 2023
# 7   \nDoes the way autistic people play need to be...
# 8   \nWhat do we mean by “neurodiversity“? Who doe...
# 9   \nIn many diagnostic reports, autistic people ...
# 10  \nAutistic People Want Work as Caregivers, But...
# 11  \nAutistic masking has become the subject of i...
# 12  \nAs an autistic person who also happens to be...
# 13  \nAutistic people, more often than not, have t...
# 14  \nJoseph Krauter is an autistic writer and tec...
# 15  \nAutistic people tend to benefit from accepta...
# 16  \nThis is a revised and updated version of my ...
# 17  \nOne of the most satisfying moments in the ne...
# 18  \nOur natural drive to conform is powerful. It...
# 19  \nContent note: This article discusses suicide...
# 20  \n“The problem isn’t exercise. It is true, unf...
# 21  \nI want to talk about grocery shopping, for o...
# 22  \n\nContent note: This essay discusses death\n...
# 23  \nI’m skeptical of TV shows with autistic char...
# 24  \nIn a recent critique group, people reading m...
# 25  \nWhat exactly is PDA, or Pathological Demand ...
# 26  \nNeurodivergent Maudie is ready to spend an a...
# 27  \nThe musician Sia recently revealed what many...
# 28  \nThe further I got into Holly Smale’s newest ...
# 29  \nIn their new book Share the Road: The Journe...
#
#                                          HTML Content Data Fetched
# 0   [\n, [[<strong>What does it mean to have a sen...   02-04-2024
# 1   [\n, [Sensory Icks: The Tags, the Seams, the I...   02-04-2024
# 2   [\n, [[What is autism, you may ask? When you s...   02-04-2024
# 3   [\n, [[No. ABA therapy cannot affirm neurodive...   02-04-2024
# 4   [\n, [Our senior editor Shannon Rosa was recen...   02-04-2024
# 5   [\n, [Investigative Documentary’s hit docu-ser...   02-04-2024
# 6   [\n, [Is it true that AI can diagnose autism?]...   02-04-2024
# 7   [\n, [Does the way autistic people play need t...   02-04-2024
# 8   [\n, [[What do we mean by “, <a href="https://...   02-04-2024
# 9   [\n, [In many diagnostic reports, autistic peo...   02-04-2024
# 10  [\n, [[Autistic People Want Work as Caregivers...   02-04-2024
# 11  [\n, [Autistic masking has become the subject ...   02-04-2024
# 12  [\n, [As an autistic person who also happens t...   02-04-2024
# 13  [\n, [Autistic people, more often than not, ha...   02-04-2024
# 14  [\n, [[Joseph Krauter is an autistic writer an...   02-04-2024
# 15  [\n, [Autistic people tend to benefit from acc...   02-04-2024
# 16  [\n, [This is a revised and updated version of...   02-04-2024
# 17  [\n, [One of the most satisfying moments in , ...   02-04-2024
# 18  [\n, [Our natural drive to conform is powerful...   02-04-2024
# 19  [\n, [[Content note: This article discusses su...   02-04-2024
# 20  [\n, [[“The problem isn’t exercise. It is true...   02-04-2024
# 21  [\n, [I want to talk about grocery shopping, f...   02-04-2024
# 22  [\n, [\n, [<span class="c1">Content note: This...   02-04-2024
# 23  [\n, [I’m skeptical of TV shows with autistic ...   02-04-2024
# 24  [\n, [In a recent critique group, people readi...   02-04-2024
# 25  [\n, [[What exactly is PDA, or Pathological De...   02-04-2024
# 26  [\n, [Neurodivergent Maudie is ready to spend ...   02-04-2024
# 27  [\n, [The musician Sia recently revealed what ...   02-04-2024
# 28  [\n, [The further I got into , [Holly Smale], ...   02-04-2024
# 29  [\n, [In their new book , [Share the Road: The...   02-04-2024

# %%
df_articles.to_csv('thinkingautismguide.csv',index=False)
