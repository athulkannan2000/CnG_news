# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

def scrape_seattlechildren_news():
    base_url = 'https://www.seattlechildrens.org'
    html_text = requests.get(base_url + '/clinics/autism-center/the-autism-blog/')
    soup = BeautifulSoup(html_text.content, 'lxml')
    
    sc = soup.find('div', class_='block')
    
    posts_data = []
    
    for index, item in enumerate(sc.find_all('li'), start=1):
        if index > 20:
            break
        
        sc_title_element = item.find('p', class_='body-large')
        if sc_title_element:
            sc_title = sc_title_element.text.strip()
            link = item.find('a')['href']
            
            # Check if link is a relative URL
            if not link.startswith('http'):
                link = base_url + link
            
            post_data = {
                'Index': index,
                'Title': sc_title,
                'Link': link,
            }
            
            posts_data.append(post_data)
        else:
            print(f"No title found for post {index}")
        
    posts_df = pd.DataFrame(posts_data)
    return posts_df


def scrape_articles(url):
    html_text = requests.get(url)
    soup = BeautifulSoup(html_text.content, 'lxml')
    
    title = soup.find('div', class_='hd').h1.text
    date = soup.find('div', class_='bd').p.text
    
    # Error handling for missing img tag
    img_tag = soup.find('div', class_='rich-text-wrapper').img
    imgurl = 'N/A' if img_tag is None else 'https://www.seattlechildrens.org/' + img_tag['src']
    
    content_tag = soup.find('div', class_='main-content-body')
    content = content_tag.text.strip() if content_tag else 'N/A'
    
    html_content = content_tag if content_tag else 'N/A'
    
    article_data = {
        'Title': title,
        'Link': url,
        'Published date': date,
        'Image URL': imgurl,
        'Text content': content,
        'HTML Content': html_content,
        'Date Fetched': pd.to_datetime('today').date()
    }
    
    return article_data

# Scrape Seattle Children's news
posts_df = scrape_seattlechildren_news()
print("Posts DataFrame:")
print(posts_df)
print("\n")

articles_data = []

for index, row in posts_df.iterrows():
    if index >= 20:
        break
    
    article_data = scrape_articles(row['Link'])
    article_data['Index'] = row['Index']
    articles_data.append(article_data)
    
articles_df = pd.DataFrame(articles_data)

articles_df = articles_df[['Index'] + [col for col in articles_df.columns if col != 'Index']]

print("Articles DataFrame:")
print(articles_df)
# Out:
# Posts DataFrame:
#     Index                                              Title  \
# 0       1               10 Autism-Friendly Summer Activities
# 1       2                Autism Acceptance Month: April 2023
# 2       3  Naturalistic Developmental Behavioral Interven...
# 3       4   Patients with Autism in the Emergency Department
# 4       5                     Suggestions for Pica Treatment
# 5       6    The Function of Stealing and Cognitive Rigidity
# 6       7                          Autism and Theory of Mind
# 7       8                                   Twins and Autism
# 8       9                                      Autism and IQ
# 9      10  Alternative and Augmentative Communication (AA...
# 10     11                   Autism and Parent Support Groups
# 11     12      Wisdom Tooth Surgery and My Child with Autism
# 12     13  Obsessive Compulsive Disorder and Autism Spect...
# 13     14                           Autism and Tic Disorders
# 14     15  How to Request Special Education Services afte...
# 15     16             Autism and a Trip to the Grocery Store
# 16     17                          Autism and Sleep Problems
# 17     18                     Autism and Dealing with Change
# 18     19                          Autism and Step-parenting
# 19     20               Divorce, Autism and Single Parenting
#
#                                                  Link
# 0   https://www.seattlechildrens.org/clinics/autis...
# 1   https://www.seattlechildrens.org/clinics/autis...
# 2   https://www.seattlechildrens.org/clinics/autis...
# 3   https://www.seattlechildrens.org/clinics/autis...
# 19  https://www.seattlechildrens.org/clinics/autis...    October 25, 2012
#
#                                             Image URL  \
# 0   https://www.seattlechildrens.org//contentasset...
# 1                                                 N/A
# 2                                                 N/A
# 3   https://www.seattlechildrens.org//globalassets...
# 4                                                 N/A
# 5                                                 N/A
# 6                                                 N/A
# 7                                                 N/A
# 8                                                 N/A
# 9                                                 N/A
# 10                                                N/A
# 11                                                N/A
# 12                                                N/A
# 13                                                N/A
# 14                                                N/A
# 15                                                N/A
# 16                                                N/A
# 17                                                N/A
# 18                                                N/A
# 19                                                N/A
#
#                                          Text content  \
# 0   The past two summers where I live, the tempera...
# 1   April 1st marks the beginning of Autism Accept...
# 2   With so many different interventions being use...
# 3   Going to the Emergency Department with any chi...
# 4   Welcome to the December edition of Ask Dr. Emi...
# 5   Welcome to the November edition of Ask Dr. Emi...
# 6   We often hear or read that those with autism l...
# 7   Today we discuss the topic of twins and autism...
# 8   An interview with Kelly Herzberg, MEd, CSP (Ke...
# 9   Communication deficit is a key feature of auti...
# 10  When my son was first diagnosed with autism at...
# 11  Waiting\nWe’re sitting in the waiting area amo...
# 12  OCD and ASD: How are they different?\nWe often...
# 13  An interview with Samuel Zinner, MD.\nSometime...
# 14  My child just received a diagnosis of autism. ...
# 15  My son has autism. His name is Arthur and he i...
# 16  An Interview with Yemi Kifle, MD\nYemiserach K...
# 17  The adjustment to the start of a new year is a...
# 18  Part 5 in our series on Autism and Family Life...
# 19  Divorce. Autism. Single Parenting.\nThese are ...
#
#                                          HTML Content Date Fetched
# 0   [\n, [\n, [<img alt="A young man wearing a blu...   2024-04-01
# 1   [\n, [\n, [\n, <div class="post-content">\n<p ...   2024-04-01
# 2   [\n, [\n, [<strong>With so many different inte...   2024-04-01
# 3   [\n, [\n, [Going to the Emergency Department w...   2024-04-01
# 4   [\n, [\n, [Welcome to the December edition of ...   2024-04-01
# 5   [\n, [\n, [Welcome to the November edition of ...   2024-04-01
# 6   [\n, [\n, [We often hear or read that those wi...   2024-04-01
# 7   [\n, [\n, [<strong>Today we discuss the topic ...   2024-04-01
# 8   [\n, [\n, [<em class="body-medium">An intervie...   2024-04-01
# 9   [\n, [\n, [Communication deficit is a key feat...   2024-04-01
# 10  [\n, [\n, [\n, <p class="body-medium">When my ...   2024-04-01
# 11  [\n, [\n, [Waiting], \n, [<strong>We’re sittin...   2024-04-01
# 12  [\n, [\n, [\n, <div>\n<h2>OCD and ASD: How are...   2024-04-01
# 13  [\n, [\n, [<em class="body-medium">An intervie...   2024-04-01
# 14  [\n, [\n, [\n, <h2>My child just received a di...   2024-04-01
# 15  [\n, [\n, [<strong>My son has autism. His name...   2024-04-01
# 16  [\n, [\n, [<em class="body-medium">An Intervie...   2024-04-01
# 17  [\n, [\n, [The adjustment to the start of a ne...   2024-04-01
# 18  [\n, [\n, [Part 5 in our series on Autism and ...   2024-04-01
# 19  [\n, [\n, [Divorce. Autism. Single Parenting.]...   2024-04-01

# %%
articles_df.to_csv('seattlechildren.csv',index=False)
